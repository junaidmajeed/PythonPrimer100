# %%
5+30*20
# Out:
# 605

# %%
(5+30)*20
# Out:
# 700

# %%
((5+30)*20)/10
# Out:
# 70.0

# %%
ali_coins = 20

# %%
fahad_coins = 10

# %%
abdullah_coins = 10

# %%
ali_coins + fahad_coins + abdullah_coins
# Out:
# 40
